# %%
from allin1 import analyze 
song_path = '/Users/alexpower/Documents/Music-Dataset-Tool/Music/wav_files/stargazing-kygo.wav'
results = analyze(song_path, out_dir='output/', keep_byproducts=False)
